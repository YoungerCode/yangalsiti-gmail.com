# %%
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt

#import geopandas
import pandas as pd
import numpy as np
#import folium
import gc
#from folium.plugins import TimeSliderChoropleth
from scipy.signal import find_peaks
import matplotlib.pyplot as plt

# %%
#Readin
dataframe = pd.read_csv("covid_19_clean_complete.csv")

# %%
#Renaming the Country/Region column
dataframe = dataframe.rename(columns={'Country/Region': 'Country'})

# %%
dataframe.tail(2)
# Out:
#                  Province/State         Country     Lat     Long     Date  \
# 17134  Turks and Caicos Islands  United Kingdom  21.694 -71.7979  3/29/20
# 17135                       NaN      MS Zaandam   0.000   0.0000  3/29/20
#
#        Confirmed  Deaths  Recovered
# 17134          4       0          0
# 17135          2       0          0

# %%
#looking for confimed cases from 1/22/20 to 3/29/20, day by day
ax = sns.lineplot(x="Date", y="Confirmed",
                  markers=True, dashes=False, data=dataframe)

# %%
#Converting Date column to date time format
dataframe['Date'] =  pd.to_datetime(dataframe['Date'], infer_datetime_format=True)

# %%
#Creating Week_Number column from Date column
dataframe['Week_Number'] = dataframe['Date'].dt.strftime('%U')

# %%
#dataframe['Date'] = pd.to_datetime(dataframe['Date'])

# %%
#Creating new dataframe to get the overview of the trends
new_df = dataframe[['Confirmed','Deaths','Date']]

# %%
new_df.head(3)
# Out:
#    Confirmed  Deaths       Date
# 0          0       0 2020-01-22
# 1          0       0 2020-01-22
# 2          0       0 2020-01-22

# %%
dataframe.head(10)
# Out:
#                  Province/State              Country      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#         Date  Confirmed  Deaths  Recovered Week_Number
# 0 2020-01-22          0       0          0          03
# 1 2020-01-22          0       0          0          03
# 2 2020-01-22          0       0          0          03
# 3 2020-01-22          0       0          0          03
# 4 2020-01-22          0       0          0          03
# 5 2020-01-22          0       0          0          03
# 6 2020-01-22          0       0          0          03
# 7 2020-01-22          0       0          0          03
# 8 2020-01-22          0       0          0          03
# 9 2020-01-22          0       0          0          03

# %%
sorted_df = dataframe.sort_values(by='Confirmed', ascending=False)

# %%
sorted_df.head(10)
# Out:
#       Province/State Country      Lat     Long       Date  Confirmed  Deaths  \
# 17109            NaN      US  37.0902 -95.7129 2020-03-29     140886    2467
# 16857            NaN      US  37.0902 -95.7129 2020-03-28     121478    2026
# 16605            NaN      US  37.0902 -95.7129 2020-03-27     101657    1581
# 17021            NaN   Italy  43.0000  12.0000 2020-03-29      97689   10779
# 16769            NaN   Italy  43.0000  12.0000 2020-03-28      92472   10023
# 16517            NaN   Italy  43.0000  12.0000 2020-03-27      86498    9134
# 16353            NaN      US  37.0902 -95.7129 2020-03-26      83836    1209
# 16265            NaN   Italy  43.0000  12.0000 2020-03-26      80589    8215
# 17085            NaN   Spain  40.0000  -4.0000 2020-03-29      80110    6803
# 16013            NaN   Italy  43.0000  12.0000 2020-03-25      74386    7503
#
#        Recovered Week_Number
# 17109       2665          13
# 16857       1072          12
# 16605        869          12
# 17021      13030          13
# 16769      12384          12
# 16517      10950          12
# 16353        681          12
# 16265      10361          12
# 17085      14709          13
# 16013       9362          12

# %%
fig, (ax2) = plt.subplots(1, 1, figsize=(8,8))

ax1 = sns.lineplot(x="Week_Number", y="Confirmed",
                  markers=True, dashes=False, data=dataframe)

ax2 = sns.lineplot(x="Week_Number", y="Deaths",
                  markers=True, dashes=False, data=dataframe)
ax2 = sns.lineplot(x="Week_Number", y="Deaths",
                  markers=True, dashes=False, data=dataframe)
ax3 = sns.lineplot(x="Week_Number", y="Recovered",
                  markers=True, dashes=False, data=dataframe)

# %%
ax = sns.scatterplot(x="Confirmed", y="Deaths", data=sorted_df)
